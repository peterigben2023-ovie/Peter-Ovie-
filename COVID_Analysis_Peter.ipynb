# %% [markdown]
# <a href="https://colab.research.google.com/github/peterigben2023-ovie/Peter-Ovie-/blob/main/COVID_Analysis_Peter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("COVID-19 Data Science Analysis")
# Out:
# COVID-19 Data Science Analysis

# %% [markdown]
# # COVID-19 Data Analysis
#
# ## 1. Introduction
#
# ## 2. Import Libraries
#
# ## 3. Load Dataset
#
# ## 4. Data Overview
#
# ## 5. Data Cleaning
#
# ## 6. Exploratory Data Analysis
#
# ## 7. Insights
#
# ## 8. Predictions
#
# ## 9. Conclusion
